# %% [markdown]
# #### Live class follow through: Python plotting matplotlib and seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
xpoints = np.array([0,5])
ypoints = np.array([0,200])
plt.plot(xpoints, ypoints)
plt.show()

# %%
plt.plot(xpoints, ypoints,'*')
